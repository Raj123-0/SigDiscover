# %% [markdown]
# # 02. Matrix Generation
#
# This notebook demonstrates how to generate mutation matrices from MAF files.

# %%
from sigdiscover.data.loaders import load_maf
from sigdiscover.matrices.sbs import build_sbs96_matrix

df = load_maf("../tests/test_data/mini_maf.maf")
matrix = build_sbs96_matrix(df)
print(matrix.head())
