# %% [markdown]
# # 05. Validation and Reporting
#
# This notebook demonstrates how to validate the extraction and generate a report.

# %%
from sigdiscover.validation.benchmark import run_benchmark_suite
from sigdiscover.validation.report import generate_validation_report

config = {
    'benchmark': {
        'synthetic_n_samples': 50,
        'synthetic_n_mutations': 1000,
        'synthetic_n_replicates': 2
    }
}

results = run_benchmark_suite(config, output_dir="../results/benchmark")
generate_validation_report(results, "../results/benchmark/report.html")
print("Generated report at ../results/benchmark/report.html")
